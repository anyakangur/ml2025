# %% [markdown]
# # Повторение ML
#
# Ноутбук взят с курса [2022 Introduction to Machine Learning and Data Analysis](https://github.com/cosmic-research-ml-edu/intro_ml_2022/tree/main).
#
# #### О задачах
#
# Этот ноутбук состоит из множества заданий, но, пожалуйста, оформляйте их как цельную историю: отчёт с вашим собственным кодом, мыслями и выводами. В некоторых из этих заданий вам нужно будет реализовать пользовательские функции, в некоторых — представить и описать графики. Пожалуйста, старайтесь писать как можно более короткий код и давать как можно более чёткие ответы.
#
# #### Оценка
#
# - В заданиях есть **вопросы**, не пропускайте их. Если вы пропускаете какой-либо вопрос, все задание считается пропущенным.
# - Если в вашем ответе есть какие-то цифры, обязательно укажите какой-нибудь код или расчеты, подтверждающие ваши результаты.
# - Обратите особое внимание на свои графики:
#     - Понятны ли они? Формы, цвета, размеры?
#     - Есть ли у них названия?
#     - Обозначены ли оси?
#     - Есть ли условные обозначения?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Основные концепции

# %% [markdown]
# **Вопрос 1.1.** Что такое supervised learning? Какая основная цель supervised learning?  В чем разница между классификацией и регрессией?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# **Вопрос 1.2.** Что такое objects и labels в задачах классификации и регрессии? Приведите как минимум три примера задач классификации и регрессии. Для каждого из этих примеров укажите несколько признаков (features), которые можно использовать в этих задачах.

# %% [markdown]
# **Ответ:**

# %% [markdown]
# **Вопрос 1.3.** Назовите как можно больше показателей качества бинарной классификации. Приведите формулу для каждого из них.

# %% [markdown]
# **Ответ:**

# %% [markdown]
# **Вопрос 1.4.** Рассчитайте все показатели, которые вы упомянули в задаче выше. Реализуйте их, не импортируя ничего, кроме `numpy`.

# %%
predictions = [1, 0, 0, 1, 0, 1, 1, 0, 1, 1, 0, 1]
ground_truth = [1, 1, 0, 1, 1, 1, 1, 0, 0, 1, 1, 0]

# Metric 1:
# YOUR CODE HERE

# Metric 2:
# YOUR CODE HERE
# ...


# Metric N:
# YOUR CODE HERE

# %% [markdown]
# **Вопрос 1.5.** Что такое ROC-AUC? Предложите два способа его расчёта (графический и вероятностный). Реализуйте хотя бы один из этих методов:

# %%
predictions = [0.8, 0.41, 0.76, 0.6, 0.35, 0.74, 0.54, 0.1, 0.51, 0.68, 0.43, 0.95]
ground_truth = [1, 1, 0, 1, 1, 1, 1, 0, 0, 1, 1, 0]

# YOUR CODE HERE

# %% [markdown]
# **Вопрос 1.6.** Что такое train и test датасеты? Какова цель разделения данных на обучающий и тестовый наборы?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# **Вопрос 1.7.** Что такое overfitting (переобучение)? Как его обнаружить? Каковы общие способы его преодоления?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# ### 2. Ирисы Фишера

# %%
from sklearn.datasets import load_iris
iris_db = load_iris()
iris_db.keys()

# %% [markdown]
# **2.1.** Какие классы и признаки присутствуют в этом наборе данных? Для каждого признака постройте гистограмму его распределения. Для каждого класса отобразите столбцы отдельным цветом.

# %%
# YOUR CODE HERE

# %% [markdown]
# **2.2.** Рассмотрим только два признака (длину и ширину чашелистика) и два класса (setosa и versicolor).
#
# Постройте двумерную диаграмму, где каждый класс будет иметь свой цвет и форму.

# %%
# YOUR CODE HERE

# %% [markdown]
# **2.3.**
# Используя набор данных из задачи 2.2, обучите 4 дерева решений глубиной `[1, 2, 3, 4]`.
#
# Для каждого дерева проверьте метрики классификации и постройте границы решений.
#
# https://scikit-learn.org/stable/auto_examples/ensemble/plot_voting_decision_regions.html

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# YOUR CODE HERE

# %% [markdown]
# **2.4.**
#
# - Используя набор данных из задачи 2.2, обучите линейную модель.
# - Постройте границы решений для этой модели и выведите метрики.
# - Какая аналитическая формула границы?

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Part 3. Grid search

# %% [markdown]
# **3.1.** Что такое гиперпараметры ML-модели и чем они отличаются от внутренних параметров?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# Теперь скачайте набор данных о раке молочной железы. Разделите его на обучающую и тестовую выборки (70% обучающей и 30% тестовой).

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer

# %%
bc_db = load_breast_cancer()

# %%
X, Y = bc_db.data, bc_db.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, stratify=Y)

# %% [markdown]
# **3.1.**
# Объясните, что такое K-fold cross-validation:

# %% [markdown]
# **Ответ:**

# %% [markdown]
# **3.2.**
# Объясните, как формируется Random Forest (далее RF) из деревьев решений (decision trees) для задач регрессии и классификации.

# %% [markdown]
# **Ответ:**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score

# %% [markdown]
# **3.3.**
#
# - Выполнить поиск по двумерной сетке для RF
# - Измерьте время обучения каждой итерации поиска
# - Предложите несколько способов ускорить весь поиск
# - Примените один из этих более быстрых методов и сравните затраченное время и качество классификации

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 4. Базовый анализ текста

# %% [markdown]
# Первая задача касается бинарной классификации слов: попробуем отделить русские фамилии от общеупотребительных русских слов.

# %%
import numpy as np

def read_list_from_file(filename, prefix=""):
    res = []
    with open(prefix + filename, "r") as input_file:
        for line in input_file.readlines():
            res.append(line.strip())
    return res

surnames = np.array(read_list_from_file("russian_surnames.txt"))
all_words = np.array(read_list_from_file("russian.txt"))

# %%
surnames_labels = np.ones_like(surnames, dtype=int)
allwords_labels = np.zeros_like(all_words, dtype=int)

X = np.concatenate([surnames, all_words])
y = np.concatenate([surnames_labels, allwords_labels])

# %% [markdown]
# **4.1.**
# Мы будем использовать слоги в качестве признаков. Почему эта идея может быть разумной?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# **4.2.**
# Реализуйте простой токенизатор:

# %%
def tokenize_word(word, token_len=3):
    ''' Function that splits word into sequence of tokens
    Args:
        word (string): input word
        token_len (int): length of each token
    Returns:
        list(str): list of tokens 
    '''
    tokens_list = []
    # YOUR CODE HERE
    
    return tokens_list

assert tokenize_word("cybersnatch") == ['cyb', 'ybe', 'ber', 'ers', 'rsn', 'sna', 'nat', 'atc', 'tch'], "smth's wrong"
print("tokenize_word: seems legit")

# %% [markdown]
# **4.3.** Извлечение признаков:
#
# - Примените токенизатор к каждому слову, чтобы разбить его на трёхсимвольные слоги.
# - Преобразуйте список токенов в вектор с помощью CountVectorizer.
# - Преобразуйте список токенов в вектор с помощью HashingVectorizer.
# - Обучите разные модели на каждом из этих наборов данных (не забудьте разделить (X, y) на тренировочную и тестовую). Постарайтсь подобрать оптимальные гиперпарамеры.
# - Сообщите результаты (время обучения и f1): какая модель лучше и почему?

# %%
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Part 5. Кластеризация

# %% [markdown]
# **5.1.** Что такое кластеризация? В чем разница между кластеризацией и мультиклассовой классификацией?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# **5.2.**
# Что такое K-means? Как это работает?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# **5.3.** Ирисы Фишера + K-means
#
# Применитк K-means к Iris датасету. Постройте результат кластеризации на 2D плоскости для каждой пары объектов.

# %%
# YOUR CODE HERE

# %% [markdown]
# **5.4.** PCA
#
# - Какая математическая концепция лежит в основе PCA
# - Для каких целей используют PCA?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# **5.5.**  Постройте кластеризацию, которую вы получили выше, на двумерной плоскости с помощью PCA.

# %%
# YOUR CODE HERE
